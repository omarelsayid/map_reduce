# %% [markdown]
# <a href="https://colab.research.google.com/github/omarelsayid/map_reduce/blob/main/map_reduce.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install mrjob
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.6/439.6 kB 24.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# **max_temp.py**

# %%
# !python max_temp.py weatherHistory.csv > output.txt
# !cat output.txt
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory /tmp/max_temp.root.20251202.205652.936075
# Running step 1 of 1...
# job output is in /tmp/max_temp.root.20251202.205652.936075/output
# Streaming final output from /tmp/max_temp.root.20251202.205652.936075/output...
# Removing temp directory /tmp/max_temp.root.20251202.205652.936075...
# "2006"	34.00555555555555
# "2007"	39.90555555555555
# "2008"	37.75555555555555
# "2015"	37.19444444444444
# "2016"	34.8111111111111
# "2012"	38.861111111111114
# "2013"	37.87222222222223
# "2014"	33.91111111111112
# "2009"	36.111111111111114
# "2010"	34.92777777777778
# "2011"	37.800000000000004
#
# 📂 Loading MRJob Results from output.txt
#
# 📊 Statistical Summary
#               Year  Max_Temperature_C
# count    11.000000          11.000000
# mean   2011.000000          36.650505
# std       3.316625           2.023739
# min    2006.000000          33.911111
# ...
